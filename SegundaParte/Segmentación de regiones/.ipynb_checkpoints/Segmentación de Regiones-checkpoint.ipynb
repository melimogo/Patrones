# %% [markdown]
# <center>
# <a href="http://www.udem.edu.co/"><img src="Escudo.png"></a>
# <h1>Reconocimiento de Patrones I y II</h1>
# <h2>Segmentación: bordes, puntos de interés y regiones</h2>
# <h3>2018-2</h3>
# </center>
#
# =================================================================================================================================

# %% [markdown]
# ## Introducción
#
# Cuando se quiere hacer reconocimiento de patrones en imagenes se hace imprescindible la extracción de información relevante de las imagenes para caracterizarlas. Esto se consigue a través de la identificación de las regiones de interés de las imágenes que se quieren clasificar. En este contexto, la binarización juega un papel fundamental para permitir la extracción de dicha información.
#
# =================================================================================================================================

# %% [markdown]
# ## Regiones: Umbrales
#
# ### Binarización de Umbral
#
# Consiste en determinar un valor $T$ llamado umbral, que permitirá llevar una imagen en escala de grises a una imagen binaria o lógica. Esto es, si un píxel de la imagen tiene un valor mayor que $T$, será llevado al valor 255 (1 en representación lógica, el equivalente al blanco). Mientras que si un píxel tiene un valor menor o igual que $T$, será llevado a 0 (equivalente al negro o fondo de la imagen)
#
# A partir del histograma de la imagen se puede partir para encontrar el umbral $T$.
#
# <img src="images/histogramas.png">
#
# ### Selección de Umbral óptimo
#
# En las imágenes de problemas reales no es común encontrarse con histogramas tan sencillos como el de la figura anterior anterior que permite encontrar el valor óptimo de $T$ de una manera tan simple. Por tal razón, se hace indispensable estudiar técnicas que permitan encontrar dicho valor $T$ óptimo.
#
# Los histogramas pueden considerarse formados por la suma de funciones de densidad de
# probabilidad. Observando la imagen mostrada en la figura anterior los dos lóbulos de los histogramas
# señalados se pueden definir como funciones de densidad, que permiten determinar la probabilidad de
# que un píxel pertenezca o no a un lóbulo, figura siguiente. En el caso del histograma bimodal (aquellos que
# poseen dos lóbulos), la función global que aproxima el histograma viene dada por:
#
# <img src="images/hist2.png">
#
# $p(z) = P_1p_1(z) + P_2p_2(z) $
#
# donde $z$ es una variable aleatoria que representa la intensidad, $p_1(z)$ y $p_2(z)$ son las funciones de
# densidad de probabilidad y $P_1$ y $P_2$ son las probabilidades a priori. Estas dos últimas son las que nos
# proporcionan la probabilidad de ocurrencia de los dos tipos de niveles de intensidad.
#
# Suponiendo las dos partes de la ecuación anterior como funciones de z,
#
# $ d_1(z) = P_1p_1(z) $  y  $ d_2(z) = P_2p_2(z)$
#
# tomaremos la decisión de clasificar el píxel como un objeto si $d_1(z) > d_2(z)$ o como píxel de fondo en
# caso contrario. El valor óptimo que nos permite determinar a partir de qué valor es un objeto o fondo
# vendrá dado entonces por el valor de $z$ para el cual $d_1(z) = d_2(z)$. Esto es,
#
# $ P_1p_1(z) = P_2p_2(z) $
#
# Si suponemos que $p_1(z)$ y $p_2(z)$ son funciones de densidad de probabilidad gaussianas, esto es,
#
# <img src="images/gaussianas.png">
#
# haciendo $z = T$ en estas expresiones, sustituyendo en las anteriores y simplificando se obtiene la ecuación de
# segundo grado en $T$:
#
# <img src="images/ecuaciones.png">
#
# Cuando resolvemos la ecuación de segundo grado se pueden obtener dos posibles soluciones,
# lo cual nos indicaría que se pueden requerir dos valores de umbral para obtener una solución óptima.
# En cambio si las desviaciones estándar son iguales, será suficiente un umbral único.
#
# <img src="images/umbral.png">
#
# Analizando la ecuación anterior, vemos que si $\sigma = 0$ o $P_1 = P_2$ , el nivel óptimo es el valor medio de las
# respectivas medias $m1$ y $m2$. La primera condición nos indica que tanto el objeto como el fondo tienen
# intensidades constantes en toda la imagen. Por otro lado, la condición de que $P_1 = P_2$ significa que los
# píxeles del objeto y del entorno tienen igual probabilidad de ocurrir, lo cual se da siempre que el
# número de píxeles del objeto sea igual al número de píxeles del entorno en una imagen.
# El procedimiento desarrollado anteriormente es aplicable a la selección de múltiples niveles, si bien
# aplicando el procedimiento en sucesivas etapas una vez que se han separado los dos lóbulos principales
# se procede a la separación en cada uno de ellos, y así sucesivamente hasta el nivel que se desee.
#
# ### Método de Otsu
#
# Otsu (1979) estudió que, al igual que en el caso de las imágenes con los histogramas bimodales,
# éstos están formados por la suma de dos funciones de densidad de probabilidad gaussianas, ecuaciones
# vistas anteriormente, donde cada gaussiana se aproxima a uno de los lóbulos. Dedujo a raíz de esto, que
# cuando las gaussianas se asemejan al histograma real, las desviaciones estándar disminuyen haciendo
# que el mejor umbral a seleccionar sea aquel que minimice la suma de las varianzas de los dos lóbulos
# del histograma.
#
# Expresado de forma matemática, dada una imagen con $L$ niveles de intensidad y
# asumiendo que el umbral buscado es $T$, las probabilidades acumuladas hasta $T$ y desde $T$ hasta $L$
# resultan ser,
#
# <img src="images/otsu1.png">
#
# se obtienen las medias y las varianzas asociadas:
#
# <img src="images/otsu2.png">
#
# y, finalmente, se obtiene la varianza ponderada:
#
# <img src="images/otsu3.png">
#
# Se elige el umbral $T$ correspondiente al nivel de intensidad que proporcione la mínima varianza
# ponderada definida en la ecuación anterior.
#
# =================================================================================================================================

# %% [markdown]
# ### Ejercicios de clase
#
# =================================================================================================================================

# %% [markdown]
# ### Veamos como aplicar el método de Otsu en la práctica

# %%
import matplotlib.pyplot as plt
from skimage import data
from skimage.filters import threshold_otsu
from skimage.color import rgb2gray
from skimage import io
import numpy as np
from PIL import Image

image = data.camera()
thresh = threshold_otsu(image)
binary = image > thresh

#Ukelele image

img_ukelele = Image.open('img/ukelele.jpeg')
# Convertir a escala de grises
img_ukelele = img_ukelele.convert('L')
# Convertir a float32
img_ukelele = np.asarray(img_ukelele,dtype=np.float32)


thresh1 = threshold_otsu(img_ukelele)
binary1 = img_ukelele > thresh1  + 58 # Con esto se mejora el umbral (tener en cuenta que la imagen tiene mucho ruido)

fig, axes = plt.subplots(ncols=3, figsize=(8, 2.5))
ax = axes.ravel()
ax[0] = plt.subplot(1, 3, 1)
ax[1] = plt.subplot(1, 3, 2)
ax[2] = plt.subplot(1, 3, 3, sharex=ax[0], sharey=ax[0])

ax[0].imshow(image, cmap=plt.cm.gray)
ax[0].set_title('Original')
ax[0].axis('off')

ax[1].hist(image.ravel(), bins=256)
ax[1].set_title('Histogram')
ax[1].axvline(thresh, color='r')

ax[2].imshow(binary, cmap=plt.cm.gray)
ax[2].set_title('Thresholded')
ax[2].axis('off')

plt.show()

#Ukelele

print('El umbral obtenido con el método de Otsu para el ukelele: ', thresh1, 'Fue mejorado manualmente (a 170)')

fig, axes = plt.subplots(ncols=3, figsize=(8, 2.5))
ax = axes.ravel()
ax[0] = plt.subplot(1, 3, 1)
ax[1] = plt.subplot(1, 3, 2)
ax[2] = plt.subplot(1, 3, 3, sharex=ax[0], sharey=ax[0])

ax[0].imshow(img_ukelele, cmap=plt.cm.gray)
ax[0].set_title('Ukelele original')
ax[0].axis('off')

ax[1].hist(img_ukelele.ravel(), bins=256)
ax[1].set_title('Histogram')
ax[1].axvline(thresh1, color='r')

ax[2].imshow(binary1, cmap=plt.cm.gray)
ax[2].set_title('Thresholded')
ax[2].axis('off')

plt.show()
# Out:
# El umbral obtenido con el método de Otsu para el ukelele:  112.060546875 Fue mejorado manualmente (a 170)

# %% [markdown]
# Comparar el tamaño de la imagen original del ukelele con el tamaño de la región de interés después de binarizar. Es decir, después de binarizar, los píxeles que interesan son los blancos. (ver solución del laboratorio 2)

# %% [markdown]
# Observar la diferencia en los histogramas de las dos imágenes presentadas.

# %% [markdown]
# ## Dando un vistazo a la librería Skimage
#
# http://scikit-image.org/docs/stable/auto_examples/index.html
#
# ## Métodos muy importantes en el reconocimiento de patrones
#
# http://scikit-image.org/docs/dev/api/skimage.measure.html
#
# =================================================================================================================================

# %% [markdown]
# ## Temas a trabajar en las presentaciones magistrales (exposiciones)

# %% [markdown]
# ## Regiones
#
# ### Método de Ridler-Calvard
#
# ### Etiquetado de componentes conexas
#
# ### Crecimiento y División

# %% [markdown]
# ## Bordes: Operadores de primera derivada
#
# ### Gradiente de una imagen
#
# ### Operadores de Sobel
#
# ### Operador de Prewitt
#
# ### Operador de Roberts
#
# ### Operador de Prewitt
#
# ### Máscaras de Kirsch
#
# ### Máscaras de Frei-Chen
#
# ## Bordes: Operadores de segunda derivada
#
# ### Operador Laplaciana
#
# ### Operador Laplaciana de la Gaussiana
#
# =================================================================================================================================

# %% [markdown]
# ## Puntos de interés
#
#
# =================================================================================================================================

# %% [markdown]
# ## Suavizado y Realzado
#
# ### Filtros de orden, filtros de media y filtrado adaptativo
#
# =================================================================================================================================

# %% [markdown]
# ## Transformación del dominio
#
# ### Fourier, coseno y Wavelets
#
# ### Filtros paso alto y filtros paso bajo
#
# ### Transformada de componentes principales
#
# =================================================================================================================================

# %% [markdown]
# ## Fundamentos de Color
#
# =================================================================================================================================

# %% [markdown]
# ## Etiquetado de regiones de una imagen (Caracterización) - Ejemplo práctico
#
# 1. Detección de umbral óptimo con el método de Otsu
# 2. Cierre de pequeños agujeros con cierre binario.
# 3. Eliminación de artefactos que tocan el borde de la imagen.
# 4. Medida de regiones de la imagen para filtrar objetos pequeños.

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

from skimage import data
from skimage.filters import threshold_otsu
from skimage.segmentation import clear_border
from skimage.measure import label, regionprops
from skimage.morphology import closing, square
from skimage.color import label2rgb


image = data.coins()[50:-50, 50:-50]

# apply threshold
thresh = threshold_otsu(image)
bw = closing(image > thresh, square(3))

# remove artifacts connected to image border
cleared = clear_border(bw)

# label image regions
label_image = label(cleared)
image_label_overlay = label2rgb(label_image, image=image)

fig, ax = plt.subplots(figsize=(10, 6))
ax.imshow(image_label_overlay)

for region in regionprops(label_image):
    # take regions with large enough areas
    if region.area >= 100:
        # draw rectangle around segmented coins
        minr, minc, maxr, maxc = region.bbox
        rect = mpatches.Rectangle((minc, minr), maxc - minc, maxr - minr,
                                  fill=False, edgecolor='red', linewidth=2)
        ax.add_patch(rect)

ax.set_axis_off()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Extracción de propiedades de una imagen

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

from skimage.draw import ellipse
from skimage.measure import label, regionprops
from skimage.transform import rotate


image = np.zeros((600, 600))

rr, cc = ellipse(300, 350, 100, 220)
image[rr, cc] = 1

image = rotate(image, angle=15, order=0)

#print(image)
#plt.imshow(image)

label_img = label(image)
regions = regionprops(label_img)

fig, ax = plt.subplots()
ax.imshow(image, cmap=plt.cm.gray)

for props in regions:
    y0, x0 = props.centroid
    orientation = props.orientation
    x1 = x0 + math.cos(orientation) * 0.5 * props.major_axis_length
    y1 = y0 - math.sin(orientation) * 0.5 * props.major_axis_length
    x2 = x0 - math.sin(orientation) * 0.5 * props.minor_axis_length
    y2 = y0 - math.cos(orientation) * 0.5 * props.minor_axis_length

    ax.plot((x0, x1), (y0, y1), '-r', linewidth=2.5)
    ax.plot((x0, x2), (y0, y2), '-r', linewidth=2.5)
    ax.plot(x0, y0, '.g', markersize=15)

    minr, minc, maxr, maxc = props.bbox
    bx = (minc, maxc, maxc, minc, minc)
    by = (minr, minr, maxr, maxr, minr)
    ax.plot(bx, by, '-b', linewidth=2.5)

ax.axis((0, 600, 600, 0))
plt.show()

for prop in region:
    print(prop, region[prop])
# Out:
# area 1155
# bbox (129, 85, 167, 124)
# bbox_area 57652
# centroid (147.7030303030303, 104.05714285714286)
# convex_area 1180
# convex_image [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# coords [[129 101]
#  [129 102]
#  [129 103]
#  ...
#  [166 106]
#  [166 107]
#  [166 108]]
# eccentricity 0.2512653198405864
# equivalent_diameter 38.34829427978659
# euler_number 1
# extent 0.7793522267206477
# filled_area 1155
# filled_image [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# image [[False False False ... False False False]
# ...

# %% [markdown]
# ## Nota
# los resultados entregados por el método regionprops pueden ser usados como características de una imagen y posteriormente implementar alguno de los modelos clasificadores que vimos en el curso para hacer el reconocimiento de patrones, teniendo en cuenta que se pueden aplicar métodos de reducción de dimensión si se considera necesario.

# %% [markdown]
# ### Ejercicios de clase
#
# 1. Usando regionprops, extraer e interpretar mímimo 10 propiedades de las imágenes ukelele y lena trabajadas durante el curso.
#
# 2. Explorar el universo de métodos de la librería Skimage y probar algunos ejemplos de los temas propuestos para las exposiciones magistrales de final de curso.

# %% [markdown]
# ## Proyecto de aula II
